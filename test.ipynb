# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
API_KEY = os.getenv("GROQ_API_KEY")

# %%
from groq import Groq

client = Groq(api_key=API_KEY)
completion = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
      {
        "role": "user",
        "content": "Расскажи что такое яблоко."
      }
    ],
    temperature=1,
    max_completion_tokens=2048,
    top_p=1,
    reasoning_effort="medium",
    stream=False,
    stop=None,
    tools=[{"type":"browser_search"}]
)

#for chunk in completion:
#    print(chunk.choices[0].delta.content or "", end="")

# %%
print(completion.choices[0].message.content)
# Out:
# **Яблоко** — это съедобный плод яблони (*Malus domestica*), одного из самых распространённых и любимых фруктов в мире. Ниже — основные сведения о нём.
#
# ---
#
# ## 1. Биологический аспект
# | Параметр | Описание |
# |----------|----------|
# | **Классификация** | Царство — Растения; отдел — Семенные; класс — Двудольные; порядок — Розоцветные; семейство — Розовые; род — *Malus*; вид — *domestica*. |
# | **Структура плода** | Яблоко — ложный плод (псевдокарп). Питательная часть образуется из завязи (мезокарп), а наружная часть – из цветолуковой листовой обертки (экзокарп). |
# | **Содержание** | В 100 г яблока содержится примерно: <br>‑ 85 г воды, <br>‑ 10–12 г сахаров (фруктоза, глюкоза, фруктан), <br>‑ 2–3 г клетчатки, <br>‑ витамины C, K, B6, ритуол, <br>‑ минералы — калий, магний, железо, <br>‑ фитохимические вещества (флавоноиды, полифенолы, антиоксиданты). |
# | **Породы** | Существует более 7 500 зарегистрированных сортов, делятся на группы по вкусу (кислые, сладкие, ароматные), сроку созревания (ранние, среднеспелые, поздние) и использованию (для еды, для кулинарии, для хранения). |
#
# ---
#
# ## 2. История и культивирование
# * **Происхождение** – дикие предки яблони родом из Центральной Азии (Казахстан, Кыргызстан). Считается, что первые одомашненные сорта появились в Греции и Римской империи около 2 тыс. лет назад.
# * **Распространение** – в Средние века яблони были завезены в Северную Европу, а в XV‑XVI вв. — в Северную и Южную Америку, Австралию и Новую Зеландию.
# * **Техника выращивания** – современная культура основывается на прививке (чаще всего на подвой *M. sylvestris*), междурядном поливе, контроле за вредителями (яблочный плодожор, мучнистый трипс) и регулярной обрезке для формирования кроны.
#
# ---
#
# ## 3. Пищевые и полезные свойства
# 1. **Энергетическая ценность** – около 52 ккал/100 г.
# 2. **Снижение риска** сердечно‑сосудистых заболеваний благодаря антиоксидантам (кверцетин, эпикатехин).
# 3. **Поддержка пищеварения**: растворимая и нерастворимая клетчатка улучшает микрофлору кишечника.
# 4. **Регуляция сахара в крови** – медленно усваиваемые углеводы и полифенолы снижают постпрандиальный гликемический отклик.
# 5. **Витамин C** усиливает иммунитет, а витамин K — коагуляцию крови и здоровье костей.
#
# ---
#
# ## 4. Кулинарное применение
# | Продукт | Пример использования |
# |--------|----------------------|
# | **Свежее** | Салаты, нарезка, соки, компоты. |
# | **Термически обработанное** | Печёные (яблочный штрудель, тарт), варёные (пюре, соус), запечённые с корицей. |
# | **Сушёное** | Яблочные чипсы, сушёные дольки, сухофрукты. |
# | **Переработка** | Сидр, яблочный уксус, мармелад, пюре‑концентрат, ароматизаторы. |
# | **Не пищевые** | Косметика (маски, кремы), ароматерапия, декоративные элементы (яблочная живопись). |
#
# ---
#
# ## 5. Хранение и сроки годности
# | Метод | Температура | Срок |
# |-------|-------------|------|
# | **Холодильник** (2‑4 °C, влажность ≈ 90 %) | До 3 мес. (зимние сорта) |
# | **Темное прохладное помещение** (0‑5 °C) | 1–2 мес. |
# | **Сушка/консервирование** | При комнатной температуре (сухие дольки) – до 1 года; в банках – до 2 лет. |
#
# ---
#
# ## 6. Интересные факты
# * **«Яблоко Ньютона»** – согласно легенде, именно падение яблока на голову Исаака Ньютона вдохновило его на формулирование закона всемирного тяготения.
# * **Символика** – в разных культурах яблоко символизирует знание (библейский рай), искушение, здоровье и бессмертие.
# * **Генетика** – геном яблони полностью расшифрован в 2010 г., что открыло возможности селекции устойчивых к болезням сортов.
#
# ---
#
# ### Кратко
# Яблоко — съедобный плод яблони, богатый витаминами, клетчаткой и антиоксидантами. Оно ценится как в свежем виде, так и в разнообразных кулинарных и промышленных продуктах, а также обладает значительным культурным и историческим значением.
